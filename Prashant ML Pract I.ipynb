# %% [markdown]
# <h1>Practcal 1

# %%
import pandas as pd

# %%
a=[4,987,8047,87,4087]

# %%
a
# Out:
# [4, 987, 8047, 87, 4087]

# %%
a = pd.Series(a)

# %%
a
# Out:
# 0       4
# 1     987
# 2    8047
# 3      87
# 4    4087
# dtype: int64

# %%
a = pd.Series(a,index=['kb','dnl','did','dh','ldbljd'])

# %%
a
# Out:
# kb       NaN
# dnl      NaN
# did      NaN
# dh       NaN
# ldbljd   NaN
# dtype: float64

# %%
data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}

#load data into a DataFrame object:
df = pd.DataFrame(data)

# %%
df.head()
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45

# %%
df.loc[1]
# Out:
# calories    380
# duration     40
# Name: 1, dtype: int64

# %%
df.loc[[0,1]]
# Out:
#    calories  duration
# 0       420        50
# 1       380        40

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
# calories    3 non-null int64
# duration    3 non-null int64
# dtypes: int64(2)
# memory usage: 128.0 bytes

# %%
data = pd.read_csv(r'C:\Users\Student\Downloads\dirtydata.csv')

# %%
data.head(40)
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
data.dropna(inplace=True)

# %%
data
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
data["Calories"].fillna(9763,inplace=True)

# %%
data
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
mean_data_Calories = data["Calories"].mean()

# %%
data["Calories"].fillna(mean_data_Calories,inplace=True)

# %%
data
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130   409.100
# 1         60  '2020/12/02'    117       145   479.000
# 2         60  '2020/12/03'    103       135   340.000
# 3         45  '2020/12/04'    109       175   282.400
# 4         45  '2020/12/05'    117       148   406.000
# 5         60  '2020/12/06'    102       127   300.000
# 6         60  '2020/12/07'    110       136   374.000
# 7        450  '2020/12/08'    104       134   253.300
# 8         30  '2020/12/09'    109       133   195.100
# 9         60  '2020/12/10'     98       124   269.000
# 10        60  '2020/12/11'    103       147   329.300
# 11        60  '2020/12/12'    100       120   250.700
# 12        60  '2020/12/12'    100       120   250.700
# 13        60  '2020/12/13'    106       128   345.300
# 14        60  '2020/12/14'    104       132   379.300
# 15        60  '2020/12/15'     98       123   275.000
# ...

# %%
x = data["Calories"].mode()[0]

# %%
x
# Out:
# 300.0

# %%
data["Date"] = pd.to_datetime(data['Date'])

# %%
data
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 0         60 2020-12-01    110       130   409.100
# 1         60 2020-12-02    117       145   479.000
# 2         60 2020-12-03    103       135   340.000
# 3         45 2020-12-04    109       175   282.400
# 4         45 2020-12-05    117       148   406.000
# 5         60 2020-12-06    102       127   300.000
# 6         60 2020-12-07    110       136   374.000
# 7        450 2020-12-08    104       134   253.300
# 8         30 2020-12-09    109       133   195.100
# 9         60 2020-12-10     98       124   269.000
# 10        60 2020-12-11    103       147   329.300
# 11        60 2020-12-12    100       120   250.700
# 12        60 2020-12-12    100       120   250.700
# 13        60 2020-12-13    106       128   345.300
# 14        60 2020-12-14    104       132   379.300
# 15        60 2020-12-15     98       123   275.000
# 16        60 2020-12-16     98       120   215.200
# ...

# %%
data.dropna(inplace=True)

# %%
data
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 0         60 2020-12-01    110       130   409.100
# 1         60 2020-12-02    117       145   479.000
# 2         60 2020-12-03    103       135   340.000
# 3         45 2020-12-04    109       175   282.400
# 4         45 2020-12-05    117       148   406.000
# 5         60 2020-12-06    102       127   300.000
# 6         60 2020-12-07    110       136   374.000
# 7        450 2020-12-08    104       134   253.300
# 8         30 2020-12-09    109       133   195.100
# 9         60 2020-12-10     98       124   269.000
# 10        60 2020-12-11    103       147   329.300
# 11        60 2020-12-12    100       120   250.700
# 12        60 2020-12-12    100       120   250.700
# 13        60 2020-12-13    106       128   345.300
# 14        60 2020-12-14    104       132   379.300
# 15        60 2020-12-15     98       123   275.000
# 16        60 2020-12-16     98       120   215.200
# ...

# %%
data.loc[7,'Duration'] =  45

# %%
data
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 0         60 2020-12-01    110       130   409.100
# 1         60 2020-12-02    117       145   479.000
# 2         60 2020-12-03    103       135   340.000
# 3         45 2020-12-04    109       175   282.400
# 4         45 2020-12-05    117       148   406.000
# 5         60 2020-12-06    102       127   300.000
# 6         60 2020-12-07    110       136   374.000
# 7         45 2020-12-08    104       134   253.300
# 8         30 2020-12-09    109       133   195.100
# 9         60 2020-12-10     98       124   269.000
# 10        60 2020-12-11    103       147   329.300
# 11        60 2020-12-12    100       120   250.700
# 12        60 2020-12-12    100       120   250.700
# 13        60 2020-12-13    106       128   345.300
# 14        60 2020-12-14    104       132   379.300
# 15        60 2020-12-15     98       123   275.000
# 16        60 2020-12-16     98       120   215.200
# ...

# %% [markdown]
# <h1>Practical 2
